# %% [markdown]
# # Assignment 8
# Analyzing Weather Data from OpenWeatherMap API

# %%
! pip install requests
# Out:
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached certifi-2024.8.30-py3-none-any.whl (167 kB)
# Downloading charset_normalizer-3.4.0-cp310-cp310-macosx_11_0_arm64.whl (120 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached urllib3-2.2.3-py3-none-any.whl (126 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2024.8.30 charset-normalizer-3.4.0 idna-3.10 requests-2.32.3 urllib3-2.2.3

# %%
import requests
import pandas as pd
import datetime
# Set your OpenWeatherMap API key
api_key = '2f12c93906e6c3d041fd528d25ea628f'

# %%
lat = 18.184135
lon = 74.610764
#https://openweathermap.org/api/one-call-3#how How to use api call
# Construct the API URL
api_url = f"http://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={api_key}"
# Send a GET request to the API
response = requests.get(api_url)
weather_data = response.json() #pass response to weather_data object(dictionary)
weather_data.keys()

dict_keys=(['cod', 'message', 'cnt', 'list', 'city'])

weather_data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1730775600,
#    'main': {'temp': 297.67,
#     'feels_like': 297.43,
#     'temp_min': 297.67,
#     'temp_max': 297.67,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 952,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 2.65, 'deg': 116, 'gust': 3.71},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-05 03:00:00'},
#   {'dt': 1730786400,
#    'main': {'temp': 299.28,
#     'feels_like': 299.28,
#     'temp_min': 299.28,
#     'temp_max': 302.5,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 951,
#     'humidity': 43,
#     'temp_kf': -3.22},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 4.06, 'deg': 98, 'gust': 4.84},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-05 06:00:00'},
#   {'dt': 1730797200,
#    'main': {'temp': 301.98,
#     'feels_like': 301.2,
#     'temp_min': 301.98,
#     'temp_max': 304.13,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 948,
#     'humidity': 35,
#     'temp_kf': -2.15},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 3.53, 'deg': 85, 'gust': 4.18},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-05 09:00:00'},
#   {'dt': 1730808000,
#    'main': {'temp': 302.53,
#     'feels_like': 301.79,
#     'temp_min': 302.53,
#     'temp_max': 302.53,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 949,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.89, 'deg': 77, 'gust': 1.93},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-05 12:00:00'},
#   {'dt': 1730818800,
#    'main': {'temp': 299.29,
#     'feels_like': 299.29,
#     'temp_min': 299.29,
#     'temp_max': 299.29,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 951,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 21},
#    'wind': {'speed': 3.04, 'deg': 65, 'gust': 3.18},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-05 15:00:00'},
#   {'dt': 1730829600,
#    'main': {'temp': 296.78,
#     'feels_like': 296.53,
#     'temp_min': 296.78,
#     'temp_max': 296.78,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 15},
#    'wind': {'speed': 2.77, 'deg': 134, 'gust': 2.7},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-05 18:00:00'},
#   {'dt': 1730840400,
#    'main': {'temp': 295.13,
#     'feels_like': 294.85,
#     'temp_min': 295.13,
#     'temp_max': 295.13,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 1.77, 'deg': 111, 'gust': 1.97},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-05 21:00:00'},
#   {'dt': 1730851200,
#    'main': {'temp': 294.08,
#     'feels_like': 293.82,
#     'temp_min': 294.08,
#     'temp_max': 294.08,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 1.76, 'deg': 97, 'gust': 1.7},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-06 00:00:00'},
#   {'dt': 1730862000,
#    'main': {'temp': 297.79,
#     'feels_like': 297.59,
#     'temp_min': 297.79,
#     'temp_max': 297.79,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 953,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 1.46, 'deg': 126, 'gust': 1.8},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-06 03:00:00'},
#   {'dt': 1730872800,
#    'main': {'temp': 302.11,
#     'feels_like': 301.46,
#     'temp_min': 302.11,
#     'temp_max': 302.11,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 952,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 2.04, 'deg': 61, 'gust': 3.3},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-06 06:00:00'},
#   {'dt': 1730883600,
#    'main': {'temp': 304.37,
#     'feels_like': 303.02,
#     'temp_min': 304.37,
#     'temp_max': 304.37,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 949,
#     'humidity': 29,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 3.13, 'deg': 37, 'gust': 3.86},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-06 09:00:00'},
#   {'dt': 1730894400,
#    'main': {'temp': 303.01,
#     'feels_like': 301.92,
#     'temp_min': 303.01,
#     'temp_max': 303.01,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 949,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 2.8, 'deg': 29, 'gust': 2.95},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-06 12:00:00'},
#   {'dt': 1730905200,
#    'main': {'temp': 298.79,
#     'feels_like': 298.35,
#     'temp_min': 298.79,
#     'temp_max': 298.79,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 4.3, 'deg': 36, 'gust': 6.71},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-06 15:00:00'},
#   {'dt': 1730916000,
#    'main': {'temp': 296.38,
#     'feels_like': 295.91,
#     'temp_min': 296.38,
#     'temp_max': 296.38,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 44,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 3.7, 'deg': 49, 'gust': 7.63},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-06 18:00:00'},
#   {'dt': 1730926800,
#    'main': {'temp': 294.38,
#     'feels_like': 293.92,
#     'temp_min': 294.38,
#     'temp_max': 294.38,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 2.05, 'deg': 100, 'gust': 1.99},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-06 21:00:00'},
#   {'dt': 1730937600,
#    'main': {'temp': 292.99,
#     'feels_like': 292.54,
#     'temp_min': 292.99,
#     'temp_max': 292.99,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 26},
#    'wind': {'speed': 1.32, 'deg': 81, 'gust': 1.56},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-07 00:00:00'},
#   {'dt': 1730948400,
#    'main': {'temp': 296.85,
#     'feels_like': 296.61,
#     'temp_min': 296.85,
#     'temp_max': 296.85,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 952,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 35},
#    'wind': {'speed': 1.42, 'deg': 90, 'gust': 1.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-07 03:00:00'},
#   {'dt': 1730959200,
#    'main': {'temp': 301.78,
#     'feels_like': 300.83,
#     'temp_min': 301.78,
#     'temp_max': 301.78,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 26},
#    'wind': {'speed': 2.31, 'deg': 62, 'gust': 3.69},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-07 06:00:00'},
#   {'dt': 1730970000,
#    'main': {'temp': 303.94,
#     'feels_like': 302.23,
#     'temp_min': 303.94,
#     'temp_max': 303.94,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 948,
#     'humidity': 24,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 10},
#    'wind': {'speed': 3.24, 'deg': 40, 'gust': 4.51},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-07 09:00:00'},
#   {'dt': 1730980800,
#    'main': {'temp': 302.16,
#     'feels_like': 301.03,
#     'temp_min': 302.16,
#     'temp_max': 302.16,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 948,
#     'humidity': 30,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 14},
#    'wind': {'speed': 3.35, 'deg': 38, 'gust': 4.36},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-07 12:00:00'},
#   {'dt': 1730991600,
#    'main': {'temp': 297.96,
#     'feels_like': 297.46,
#     'temp_min': 297.96,
#     'temp_max': 297.96,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 4.08, 'deg': 44, 'gust': 6.35},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-07 15:00:00'},
#   {'dt': 1731002400,
#    'main': {'temp': 295.72,
#     'feels_like': 295.31,
#     'temp_min': 295.72,
#     'temp_max': 295.72,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 2.17, 'deg': 71, 'gust': 2.39},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-07 18:00:00'},
#   {'dt': 1731013200,
#    'main': {'temp': 294.15,
#     'feels_like': 293.79,
#     'temp_min': 294.15,
#     'temp_max': 294.15,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 949,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.22, 'deg': 101, 'gust': 2.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-07 21:00:00'},
#   {'dt': 1731024000,
#    'main': {'temp': 293.1,
#     'feels_like': 292.72,
#     'temp_min': 293.1,
#     'temp_max': 293.1,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 949,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.04, 'deg': 105, 'gust': 2.1},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-08 00:00:00'},
#   {'dt': 1731034800,
#    'main': {'temp': 296.69,
#     'feels_like': 296.43,
#     'temp_min': 296.69,
#     'temp_max': 296.69,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 952,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.8, 'deg': 124, 'gust': 3.79},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-08 03:00:00'},
#   {'dt': 1731045600,
#    'main': {'temp': 301.37,
#     'feels_like': 300.8,
#     'temp_min': 301.37,
#     'temp_max': 301.37,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.27, 'deg': 98, 'gust': 5.16},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-08 06:00:00'},
#   {'dt': 1731056400,
#    'main': {'temp': 303.44,
#     'feels_like': 302.1,
#     'temp_min': 303.44,
#     'temp_max': 303.44,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 948,
#     'humidity': 29,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.33, 'deg': 93, 'gust': 3.92},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-08 09:00:00'},
#   {'dt': 1731067200,
#    'main': {'temp': 301.81,
#     'feels_like': 300.92,
#     'temp_min': 301.81,
#     'temp_max': 301.81,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 948,
#     'humidity': 33,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.36, 'deg': 103, 'gust': 2.35},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-08 12:00:00'},
#   {'dt': 1731078000,
#    'main': {'temp': 297.7,
#     'feels_like': 297.26,
#     'temp_min': 297.7,
#     'temp_max': 297.7,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.43, 'deg': 53, 'gust': 2.75},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-08 15:00:00'},
#   {'dt': 1731088800,
#    'main': {'temp': 295.89,
#     'feels_like': 295.5,
#     'temp_min': 295.89,
#     'temp_max': 295.89,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 950,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.75, 'deg': 97, 'gust': 5.89},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-08 18:00:00'},
#   {'dt': 1731099600,
#    'main': {'temp': 294.48,
#     'feels_like': 294.1,
#     'temp_min': 294.48,
#     'temp_max': 294.48,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 949,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.92, 'deg': 115, 'gust': 3},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-08 21:00:00'},
#   {'dt': 1731110400,
#    'main': {'temp': 293.21,
#     'feels_like': 292.81,
#     'temp_min': 293.21,
#     'temp_max': 293.21,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.25, 'deg': 131, 'gust': 2.34},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-09 00:00:00'},
#   {'dt': 1731121200,
#    'main': {'temp': 296.83,
#     'feels_like': 296.53,
#     'temp_min': 296.83,
#     'temp_max': 296.83,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 952,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.4, 'deg': 112, 'gust': 3.24},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-09 03:00:00'},
#   {'dt': 1731132000,
#    'main': {'temp': 301.87,
#     'feels_like': 301.03,
#     'temp_min': 301.87,
#     'temp_max': 301.87,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 34,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.72, 'deg': 93, 'gust': 3.53},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-09 06:00:00'},
#   {'dt': 1731142800,
#    'main': {'temp': 303.66,
#     'feels_like': 302.17,
#     'temp_min': 303.66,
#     'temp_max': 303.66,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 948,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.64, 'deg': 82, 'gust': 2.57},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-09 09:00:00'},
#   {'dt': 1731153600,
#    'main': {'temp': 301.9,
#     'feels_like': 300.99,
#     'temp_min': 301.9,
#     'temp_max': 301.9,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 948,
#     'humidity': 33,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.82, 'deg': 121, 'gust': 1.83},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-09 12:00:00'},
#   {'dt': 1731164400,
#    'main': {'temp': 298.05,
#     'feels_like': 297.56,
#     'temp_min': 298.05,
#     'temp_max': 298.05,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.04, 'deg': 93, 'gust': 2.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-09 15:00:00'},
#   {'dt': 1731175200,
#    'main': {'temp': 296.03,
#     'feels_like': 295.52,
#     'temp_min': 296.03,
#     'temp_max': 296.03,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 44,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.65, 'deg': 87, 'gust': 4.76},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-09 18:00:00'},
#   {'dt': 1731186000,
#    'main': {'temp': 294.42,
#     'feels_like': 293.96,
#     'temp_min': 294.42,
#     'temp_max': 294.42,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.21, 'deg': 99, 'gust': 3.19},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-09 21:00:00'},
#   {'dt': 1731196800,
#    'main': {'temp': 293.16,
#     'feels_like': 292.7,
#     'temp_min': 293.16,
#     'temp_max': 293.16,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.32, 'deg': 114, 'gust': 2.34},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-10 00:00:00'}],
#  'city': {'id': 1277091,
#   'name': 'Bārāmati',
#   'coord': {'lat': 18.1841, 'lon': 74.6108},
#   'country': 'IN',
#   'population': 53919,
#   'timezone': 19800,
#   'sunrise': 1730768565,
#   'sunset': 1730809652}}

# %%
len(weather_data['list'])
# Out:
# 40

# %%
weather_data['list'][0]['weather'][0]['description']
# Out:
# 'clear sky'

# %%
temperatures = [item['main']['temp'] for item in weather_data['list']]
timestamps = [pd.to_datetime(item['dt'], unit='s') for item in weather_data['list']]
temperature = [item['main']['temp'] for item in weather_data['list']]
humidity = [item['main']['humidity'] for item in weather_data['list']]
wind_speed = [item['wind']['speed'] for item in weather_data['list']]
weather_description = [item['weather'][0]['description'] for item in weather_data['list']]
# Create a pandas DataFrame with the extracted weather data
weather_df = pd.DataFrame({
'Timestamp': timestamps,
'Temperature': temperatures,
'humidity': humidity,
'wind_speed': wind_speed,
'weather_description': weather_description,
})
# Set the Timestamp column as the DataFrame's index
weather_df.set_index('Timestamp', inplace=True)
max_temp = weather_df['Temperature'].max()
max_temp
# Out:
# np.float64(304.37)

# %%
min_temp = weather_df['Temperature'].min()
min_temp
# Out:
# np.float64(292.99)

# %%
# Handling missing values
weather_df.fillna(0, inplace=True) # Replace missing values with 0 or appropriate value
# Handling inconsistent format (if applicable)
weather_df['Temperature'] = weather_df['Temperature'].apply(lambda x: x - 273.15 if isinstance(x, float)else x)

# %%
print(weather_df)
# Out:
#                      Temperature  humidity  wind_speed weather_description
# Timestamp
# 2024-11-05 03:00:00        24.52        48        2.65           clear sky
# 2024-11-05 06:00:00        26.13        43        4.06           clear sky
# 2024-11-05 09:00:00        28.83        35        3.53           clear sky
# 2024-11-05 12:00:00        29.38        36        1.89           clear sky
# 2024-11-05 15:00:00        26.14        40        3.04          few clouds
# 2024-11-05 18:00:00        23.63        51        2.77          few clouds
# 2024-11-05 21:00:00        21.98        56        1.77           clear sky
# 2024-11-06 00:00:00        20.93        61        1.76           clear sky
# 2024-11-06 03:00:00        24.64        49        1.46           clear sky
# 2024-11-06 06:00:00        28.96        37        2.04           clear sky
# 2024-11-06 09:00:00        31.22        29        3.13           clear sky
# 2024-11-06 12:00:00        29.86        32        2.80           clear sky
# 2024-11-06 15:00:00        25.64        36        4.30           clear sky
# 2024-11-06 18:00:00        23.23        44        3.70           clear sky
# 2024-11-06 21:00:00        21.23        52        2.05           clear sky
# 2024-11-07 00:00:00        19.84        58        1.32    scattered clouds
# 2024-11-07 03:00:00        23.70        51        1.42    scattered clouds
# 2024-11-07 06:00:00        28.63        32        2.31    scattered clouds
# 2024-11-07 09:00:00        30.79        24        3.24           clear sky
# 2024-11-07 12:00:00        29.01        30        3.35          few clouds
# 2024-11-07 15:00:00        24.81        37        4.08           clear sky
# 2024-11-07 18:00:00        22.57        49        2.17           clear sky
# 2024-11-07 21:00:00        21.00        57        2.22           clear sky
# 2024-11-08 00:00:00        19.95        60        2.04           clear sky
# 2024-11-08 03:00:00        23.54        51        2.80           clear sky
# 2024-11-08 06:00:00        28.22        37        4.27           clear sky
# 2024-11-08 09:00:00        30.29        29        3.33           clear sky
# 2024-11-08 12:00:00        28.66        33        2.36           clear sky
# 2024-11-08 15:00:00        24.55        40        2.43           clear sky
# 2024-11-08 18:00:00        22.74        49        3.75           clear sky
# 2024-11-08 21:00:00        21.33        55        2.92           clear sky
# 2024-11-09 00:00:00        20.06        59        2.25           clear sky
# 2024-11-09 03:00:00        23.68        49        2.40           clear sky
# 2024-11-09 06:00:00        28.72        34        3.72           clear sky
# 2024-11-09 09:00:00        30.51        27        2.64           clear sky
# 2024-11-09 12:00:00        28.75        33        1.82           clear sky
# 2024-11-09 15:00:00        24.90        37        2.04           clear sky
# 2024-11-09 18:00:00        22.88        44        3.65           clear sky
# 2024-11-09 21:00:00        21.27        52        3.21           clear sky
# 2024-11-10 00:00:00        20.01        57        2.32           clear sky
